# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
db = pd.read_csv('cars.csv')

vc = db['Company Names'].value_counts().sort_values()
vc = vc[vc>=24]
labels = vc.index
plt.pie(vc, labels = labels)
db['Company Names'].value_counts()
# Out:
# Company Names
# NISSAN               133
# PORSCHE               87
# VOLKSWAGEN            75
# KIA                   64
# MAZDA                 60
# GMC                   55
# PEUGEOT               53
# CHEVROLET             52
# MITSUBISHI            45
# BMW                   41
# JAGUAR LAND ROVER     38
# ROLLS ROYCE           30
# FORD                  25
# LAMBORGHINI           24
# ACURA                 24
# MERCEDES              21
# TOYOTA                21
# AUDI                  20
# CADILLAC              18
# TATA MOTORS           16
# HYUNDAI               12
# ASTON MARTIN          11
# JEEP                  10
# BUGATTI               10
# TESLA                  9
# FERRARI                8
# VOLVO                  6
# HONDA                  5
# MAHINDRA               2
# BENTLEY                1
# MARUTI SUZUKI          1
# Name: count, dtype: int64
