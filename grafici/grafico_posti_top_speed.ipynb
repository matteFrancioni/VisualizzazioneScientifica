# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
db = pd.read_csv('cars.csv')
plt.barh(db.Seats, db['Total Speed'])
plt.ylabel("Posti")
plt.xlabel("top speed")
plt.yticks(np.arange(0, 13))
plt.title("Posti / Top speed")
plt.show()
